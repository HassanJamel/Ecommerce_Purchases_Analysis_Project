# %% [markdown]
# # **Ecommerce Purchases Analysis Project**

# %% [markdown]
# **Author Name:** Eng.Hassan Jameel Ahmed\
# **Email:** hassan.j.a@hotmail.com\
# **linkedin:** [www.linkedin.com/in/hassanjameel](www.linkedin.com/in/hassanjameel)\
# **kaggle:** [www.linkedin.com/in/hassanjameel](https://www.kaggle.com/hassanjameelahmed)\
# **Github:** [https://github.com/HassanJamel](https://github.com/HassanJamel)\
# **Mobile no:** 0509684720

# %%
from IPython.display import Image
Image(filename = "3.PNG", width = 800, height = 600)

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Improt the dataset
Ecommerce = pd.read_csv('ecommerce-purchases.csv')

# %% [markdown]
# #### Check the head of the DataFrame

# %%
Ecommerce.head(5)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# #### Check the tail of the DataFrame

# %%
Ecommerce.tail(5)
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %% [markdown]
# #### Check the rows and columns count and data types

# %%
Ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Check any missing data in DataFrame

# %%
Ecommerce.isna().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
# No any missing data
Ecommerce.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Show description DataFrame

# %%
Ecommerce.describe().round(2)
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04          10000.00        10000.00
# mean   2.341374e+15            907.22           50.35
# std    2.256103e+15           1589.69           29.02
# min    6.040186e+10              0.00            0.00
# 25%    3.056322e+13            280.00           25.15
# 50%    8.699942e+14            548.00           50.50
# 75%    4.492298e+15            816.00           75.77
# max    6.012000e+15           9993.00           99.99

# %% [markdown]
# #### What were the highest, lowest and median purchase prices?

# %%
Ecommerce['Purchase Price'].max()
# Out:
# 99.99

# %%
Ecommerce['Purchase Price'].median()
# Out:
# 50.504999999999995

# %%
Ecommerce['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# #### How many people have English 'en' as their Language of choice on the website?

# %%
Ecommerce['Language'].value_counts()
# Out:
# Language
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: count, dtype: int64

# %%
Ecommerce[Ecommerce['Language'] =='en']
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %%
# Show how is the length
len(Ecommerce[Ecommerce['Language'] =='en'].count())
# Out:
# 14

# %% [markdown]
# #### How many people have the job title of "Purchasing manager " ?

# %%
Ecommerce['Job'].value_counts()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: count, Length: 623, dtype: int64

# %%
Ecommerce[Ecommerce['Job'] =='Purchasing manager']
# Out:
#                                                 Address    Lot AM or PM  \
# 43    92982 Christopher Harbor\nLake Brianahaven, NJ...  60 Uq       PM
# 75                PSC 6723, Box 3476\nAPO AP 56767-0500  75 Td       AM
# 1511   1080 Vickie Overpass\nWest Thomas, KY 53457-2798  42 mc       PM
# 1519  99061 Baker Harbor Apt. 618\nHarrisburgh, CT 7...  27 hL       AM
# 1532        995 Jacob Harbors\nNew Oliviafurt, IN 04538  32 Wm       AM
# 1710  135 Chavez Rest Apt. 382\nEast Karinaberg, OH ...  61 XF       AM
# 1838      136 Cameron Spur\nShannonmouth, NJ 07674-7810  10 GD       AM
# 2861  42005 Nelson Heights\nPort Christopher, RI 900...  22 DT       PM
# 3052  3377 Kimberly Run\nLake Crystalmouth, ND 28041...  06 To       AM
# 3624  2552 Rodriguez Underpass Apt. 724\nNew Alexand...  12 sd       AM
# 3985  64311 Young Mills Apt. 856\nEast Michael, VT 7...  22 eK       AM
# 4173  990 Danielle Estates Suite 813\nSouth Andrew, ...  52 eH       PM
# ...

# %%
# Show how is the length
len(Ecommerce[Ecommerce['Job'] =='Purchasing manager'])
# Out:
# 27

# %% [markdown]
# #### How many people made the purchase during the AM and how many people made the purchase during PM ?

# %%
Ecommerce['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
# Show EDA
Ecommerce['AM or PM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='AM or PM'>

# %%
Ecommerce[Ecommerce['AM or PM'] == 'PM']
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# ...                                                 ...    ...      ...
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...

# %%
Ecommerce[Ecommerce['AM or PM'] == 'AM']
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# ...                                                 ...    ...      ...
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# #### What are the 5 most common Job Titles?

# %%
Ecommerce['Job'].value_counts().head(5)
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: count, dtype: int64

# %% [markdown]
# #### What is the email of the person with the following Credit Card Number: 4926535242672853

# %%
Ecommerce[Ecommerce['Credit Card'] == 4926535242672853]
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672853       09/21               188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %%
# Show some fields with condition
Ecommerce[Ecommerce['Credit Card'] == 4926535242672853][['Company','Email','Language']]
# Out:
#                     Company                         Email Language
# 1234  Cole, King and Bowers  bondellen@williams-garza.com       ru

# %% [markdown]
# #### How many people have American Express as their Credit Card Provider *and made a purchase above  95 USD ?

# %%
Ecommerce[(Ecommerce['CC Provider'] == 'American Express')
         & (Ecommerce['Purchase Price'] > 95)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# ...

# %%
len(Ecommerce[(Ecommerce['CC Provider'] == 'American Express')
         & (Ecommerce['Purchase Price'] > 95)])
# Out:
# 39

# %% [markdown]
# # Thank you
